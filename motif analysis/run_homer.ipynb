# %%
# !apt-get install ghost script
# !wget http://homer.ucsd.edu/homer/configureHomer.pl
# !perl configureHomer.pl -install
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package ghost
# E: Unable to locate package script
# --2024-05-13 20:13:54--  http://homer.ucsd.edu/homer/configureHomer.pl
# Resolving homer.ucsd.edu (homer.ucsd.edu)... 169.228.63.226
# Connecting to homer.ucsd.edu (homer.ucsd.edu)|169.228.63.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27679 (27K) [application/x-perl]
# Saving to: ‘configureHomer.pl’
#
# configureHomer.pl   100%[===================>]  27.03K  --.-KB/s    in 0.1s
#
# 2024-05-13 20:13:55 (180 KB/s) - ‘configureHomer.pl’ saved [27679/27679]
#
#
# 	Current base directory for HOMER is /content/./
#
# --2024-05-13 20:13:55--  http://homer.ucsd.edu/homer/update.txt
# Resolving homer.ucsd.edu (homer.ucsd.edu)... 169.228.63.226
# Connecting to homer.ucsd.edu (homer.ucsd.edu)|169.228.63.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17857 (17K) [text/plain]
# Saving to: ‘/content/.//update.txt’
#
# /content/.//update. 100%[===================>]  17.44K   115KB/s    in 0.2s
#
# 2024-05-13 20:13:55 (115 KB/s) - ‘/content/.//update.txt’ saved [17857/17857]
#
# 	Updating Settings...
# `wget -O 0.35307387968442.tmp http://homer.ucsd.edu/homer/configureHomer.pl`;
# --2024-05-13 20:13:55--  http://homer.ucsd.edu/homer/configureHomer.pl
# Resolving homer.ucsd.edu (homer.ucsd.edu)... 169.228.63.226
# Connecting to homer.ucsd.edu (homer.ucsd.edu)|169.228.63.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27679 (27K) [application/x-perl]
# Saving to: ‘0.35307387968442.tmp’
#
# 0.35307387968442.tm 100%[===================>]  27.03K   178KB/s    in 0.2s
#
# 2024-05-13 20:13:56 (178 KB/s) - ‘0.35307387968442.tmp’ saved [27679/27679]
#
# 	configureHomer.pl script is up-to-date
# 	Packages to Install...
# 		homer ->
#
# 	Checking for standard utilities and 3rd party software:
#
# 		(Note: seqlogo, gs, and blat no longer required)
# 	Checking for wget... /usr/bin/wget
# 	Checking for cut... /usr/bin/cut
# 	Checking for gcc... /usr/bin/gcc
# 	Checking for g++... /usr/bin/g++
# 	Checking for zip... /usr/bin/zip
# 	Checking for unzip... /usr/bin/unzip
# 	Checking for make... /usr/bin/make
# 	Checking for tar... /usr/bin/tar
# 	Checking for gunzip... /usr/bin/gunzip
# 	Checking for gzip... /usr/bin/gzip
#
# 	All auxilary programs found.
#
# 	Pausing for 3 seconds (hit ctrl-C to stop)
# 	Installing: homer
# 		Downloading...
# --2024-05-13 20:13:59--  http://homer.ucsd.edu/homer/data/software/homer.v5.0.1.zip
# Resolving homer.ucsd.edu (homer.ucsd.edu)... 169.228.63.226
# Connecting to homer.ucsd.edu (homer.ucsd.edu)|169.228.63.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38163801 (36M) [application/zip]
# Saving to: ‘homer.package.zip’
#
# homer.package.zip   100%[===================>]  36.40M  11.9MB/s    in 3.1s
#
# 2024-05-13 20:14:02 (11.9 MB/s) - ‘homer.package.zip’ saved [38163801/38163801]
#
# 		Unzipping...
# 		Finished Installing homer
#
# In file included from /usr/include/stdio.h:894,
#                  from Motif.h:17,
#                  from Motif.cpp:19:
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘char** findBestSeeds(CommandLine*, XMerData*, int*, int, int&)’ at Motif.cpp:2904:11:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void findMotifs(CommandLine*, XMerData*)’ at Motif.cpp:177:12:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void findMotifs(CommandLine*, XMerData*)’ at Motif.cpp:173:12:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# homer.cpp: In function ‘int main(int, char**)’:
# homer.cpp:71:29: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#    71 |                 (void)system(c);
#       |                       ~~~~~~^~~
# homer.cpp:82:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#    82 |                         (void)system(c);
#       |                               ~~~~~~^~~
# SeqTag.cpp: In member function ‘void TagLibrary::makeDirectory()’:
# SeqTag.cpp:6545:21: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6545 |         (void)system(filename);
#       |               ~~~~~~^~~~~~~~~~
# SeqTag.cpp:6549:21: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6549 |         (void)system(filename);
#       |               ~~~~~~^~~~~~~~~~
# SeqTag.cpp: In function ‘char* unzipFileIfNeeded(char*, int&, int&)’:
# SeqTag.cpp:6581:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6581 |                         (void)system(command);
#       |                               ~~~~~~^~~~~~~~~
# SeqTag.cpp:6588:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6588 |                         (void)system(command);
#       |                               ~~~~~~^~~~~~~~~
# SeqTag.cpp:6595:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6595 |                         (void)system(command);
#       |                               ~~~~~~^~~~~~~~~
# SeqTag.cpp:6603:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6603 |                         (void)system(command);
#       |                               ~~~~~~^~~~~~~~~
# SeqTag.cpp: In function ‘void rezipFileIfNeeded(char*, int)’:
# SeqTag.cpp:6618:29: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6618 |                 (void)system(command);
#       |                       ~~~~~~^~~~~~~~~
# SeqTag.cpp: In member function ‘void TagLibrary::readPEAlignment(char*, int, int, int)’:
# SeqTag.cpp:6905:29: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6905 |                 (void)system(fname);
#       |                       ~~~~~~^~~~~~~
# SeqTag.cpp:6907:29: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  6907 |                 (void)system(fname);
#       |                       ~~~~~~^~~~~~~
# SeqTag.cpp: In member function ‘void UniqMapChrs::loadData()’:
# SeqTag.cpp:18548:20: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
# 18548 |         (void)fread(&psize,sizeof(unsigned int),1,fpp);
#       |               ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# SeqTag.cpp:18550:20: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
# 18550 |         (void)fread(&nsize,sizeof(unsigned int),1,fpn);
#       |               ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# SeqTag.cpp:18560:20: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
# 18560 |         (void)fread(pstrand,sizeof(unsigned char),maxIndex,fpp);
#       |               ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# SeqTag.cpp:18561:20: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
# 18561 |         (void)fread(nstrand,sizeof(unsigned char),maxIndex,fpn);
#       |               ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# makeUCSCfile.cpp: In function ‘int main(int, char**)’:
# makeUCSCfile.cpp:325:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   325 |                         (void)system(str);
#       |                               ~~~~~~^~~~~
# makeUCSCfile.cpp:336:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   336 |                         (void)system(str);
#       |                               ~~~~~~^~~~~
# makeUCSCfile.cpp:339:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   339 |                         (void)system(str);
#       |                               ~~~~~~^~~~~
# homerTools.cpp: In function ‘void decontaminateProgram(int, char**)’:
# homerTools.cpp:1703:45: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1703 |                                 (void)system("sleep 1");
#       |                                       ~~~~~~^~~~~~~~~~~
# homerTools.cpp:1711:29: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1711 |                 (void)system(command);
#       |                       ~~~~~~^~~~~~~~~
# homerTools.cpp:1713:29: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1713 |                 (void)system(command);
#       |                       ~~~~~~^~~~~~~~~
# homerTools.cpp: In function ‘void specialUniqMapProgram(int, char**)’:
# homerTools.cpp:1788:21: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1788 |         (void)system(command);
#       |               ~~~~~~^~~~~~~~~
# homerTools.cpp: In function ‘void extractProgram(int, char**)’:
# homerTools.cpp:1597:17: warning: argument 2 null where non-null expected [-Wnonnull]
#  1597 |         if (stat(genomeDir,buf) != 0) {
#       |             ~~~~^~~~~~~~~~~~~~~
# In file included from homerTools.h:6,
#                  from homerTools.cpp:16:
# /usr/include/x86_64-linux-gnu/sys/stat.h:205:12: note: in a call to function ‘int stat(const char*, stat*)’ declared ‘nonnull’
#   205 | extern int stat (const char *__restrict __file,
#       |            ^~~~
# analyzeHiC.cpp: In function ‘int main(int, char**)’:
# analyzeHiC.cpp:1375:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1375 |                         (void)system(cmd);
#       |                               ~~~~~~^~~~~
# analyzeHiC.cpp:1380:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1380 |                         (void)system(cmd);
#       |                               ~~~~~~^~~~~
# analyzeHiC.cpp:1385:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1385 |                         (void)system(cmd);
#       |                               ~~~~~~^~~~~
# analyzeHiC.cpp:1390:37: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1390 |                         (void)system(cmd);
#       |                               ~~~~~~^~~~~
# analyzeHiC.cpp: In function ‘void printCircosFiles(char*, int, TagLibrary*, PeakLibrary*, PeakLibrary*, int, int, int, int, char**, int, char**, int, char**, int, TagLibrary*)’:
# analyzeHiC.cpp:1796:29: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1796 |                 (void)system(command);
#       |                       ~~~~~~^~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from Motif2.h:17,
#                  from Motif2.cpp:16:
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void BgSequence::printAll(FILE*)’ at Motif2.cpp:5355:9:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void BgSequence::printFASTA(FILE*, int)’ at Motif2.cpp:5407:9,
#     inlined from ‘void BgSequence::printFASTA(FILE*)’ at Motif2.cpp:5396:12:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void BgSequence::printFASTA(FILE*, int)’ at Motif2.cpp:5407:9:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void BgSequence::printSeq(FILE*, int)’ at Motif2.cpp:5432:10,
#     inlined from ‘void BgSequence::printSeq(FILE*)’ at Motif2.cpp:5423:10:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void BgSequence::printFASTA(FILE*, int)’ at Motif2.cpp:5407:9,
#     inlined from ‘void BgSequenceArray::printAllSequencesFASTA(FILE*)’ at Motif2.cpp:7314:22:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void BgSequence::printFASTA(FILE*, int)’ at Motif2.cpp:5407:9,
#     inlined from ‘void BgSequenceArray::printSelectedSequencesFASTA(FILE*)’ at Motif2.cpp:7334:27:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
# In function ‘int fprintf(FILE*, const char*, ...)’,
#     inlined from ‘void BgSequence::printSeq(FILE*, int)’ at Motif2.cpp:5430:10,
#     inlined from ‘void BgSequenceArray::printSeqFile(FILE*)’ at Motif2.cpp:7367:25:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:105:24: warning: ‘%s’ directive argument is null [-Wformat-overflow=]
#   105 |   return __fprintf_chk (__stream, __USE_FORTIFY_LEVEL - 1, __fmt,
#       |          ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   106 |                         __va_arg_pack ());
#       |                         ~~~~~~~~~~~~~~~~~
#
# 	Software Installed.  If not done so already, add the homer programs to your executable path.
#
# 	Add this line to your .bash_profile or .bashrc file (or other depending on your shell):
# 		PATH=$PATH:/content/.//bin/
#
#
# 	Simply typing "findMotifs.pl" should work before running Homer.

# %%
import os
os.environ['PATH'] += ":/content/bin"

# %%
# !findMotifs.pl output.fa fasta output_dir
# Out:
# Selected Options:
# 	Input file = output.fa
# 	Promoter Set = fasta
# 	Output Directory = output_dir
#
# 	!Warning - no background FASTA file specified (Highly recommended)
# 	!Your input sequences will be randomized to serve as a background instead.
#
# 	Found 1000 sequences
# 	Using custom gene IDs for GO analysis
# 	Parsing FASTA format files...
# 	Found 1000 sequences
# 	Found 5000 sequences
#
# 	Progress: Step4 - removing redundant promoters
#
# 	Progress: Step5 - adjusting background sequences for GC/CpG content...
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 249 bp
# 		6000 total
#
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 	Freq	Bin	Count
# 	0.3	2	5
# 	0.35	3	176
# 	0.4	4	1084
# 	0.45	5	2603
# 	0.5	6	1688
# 	0.6	7	442
# 	0.7	8	2
# 	Bin	# Targets	# Background	Background Weight
# 	3	7	169	0.207
# 	4	150	934	0.802
# 	5	513	2090	1.226
# 	6	298	1390	1.070
# 	7	32	410	0.390
#
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	5993 total sequences read
# 	Autonormalization: 1-mers (4 total)
# 		A	28.21%	28.21%	1.000
# 		C	21.79%	21.79%	1.000
# 		G	21.79%	21.79%	1.000
# 		T	28.21%	28.21%	1.000
# 	Autonormalization: 2-mers (16 total)
# 		AA	8.95%	8.15%	1.098
# 		CA	7.03%	6.24%	1.128
# 		GA	6.75%	6.03%	1.119
# 		TA	5.46%	7.79%	0.701
# 		AC	4.69%	6.25%	0.751
# 		CC	4.29%	4.91%	0.874
# 		GC	6.07%	4.60%	1.319
# 		TC	6.75%	6.03%	1.119
# 		AG	6.08%	6.02%	1.011
# 		CG	4.39%	4.63%	0.948
# 		GG	4.29%	4.91%	0.874
# 		TG	7.03%	6.24%	1.128
# 		AT	8.50%	7.78%	1.092
# 		CT	6.08%	6.02%	1.011
# 		GT	4.69%	6.25%	0.751
# 		TT	8.95%	8.15%	1.098
# 	Autonormalization: 3-mers (64 total)
# 	Normalization weights can be found in file: output_dir/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 	...............................................................................
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# 		A	28.21%	28.22%	1.000
# 		C	21.79%	21.78%	1.000
# 		G	21.79%	21.78%	1.000
# 		T	28.21%	28.22%	1.000
# 	Autonormalization: 2-mers (16 total)
# 		AA	8.95%	8.45%	1.059
# 		CA	7.03%	6.47%	1.087
# 		GA	6.75%	6.25%	1.078
# 		TA	5.46%	7.05%	0.775
# 		AC	4.69%	5.74%	0.817
# 		CC	4.29%	4.70%	0.913
# 		GC	6.07%	5.08%	1.195
# 		TC	6.75%	6.25%	1.078
# 		AG	6.08%	6.02%	1.011
# 		CG	4.39%	4.59%	0.956
# 		GG	4.29%	4.70%	0.913
# 		TG	7.03%	6.47%	1.087
# 		AT	8.50%	8.01%	1.061
# 		CT	6.08%	6.02%	1.011
# 		GT	4.69%	5.74%	0.817
# 		TT	8.95%	8.45%	1.059
# 	Autonormalization: 3-mers (64 total)
#
# 	Progress: Step6 - Gene Ontology Enrichment Analysis
# 	Skipping...
#
# 	Progress: Step7 - Known motif enrichment
#
# 	Reading input files...
# 	5993 total sequences read
# 	1048 motifs loaded
# 	Cache length = 11180
# 	Using hypergeometric scoring
# 	Checking enrichment of 1048 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Preparing HTML output with sequence logos...
# 		1 of 1048 (1e-184) PABPC1(?)/MEL-PABC1-CLIP-Seq(GSE69755)/Homer
# 		2 of 1048 (1e-172) polyAsite/CPSF/Homer
# 		3 of 1048 (1e-45) Ap4(bHLH)/AML-Tfap4-ChIP-Seq(GSE45738)/Homer
# 		4 of 1048 (1e-36) Mef2c(MADS)/GM12878-Mef2c-ChIP-Seq(GSE32465)/Homer
# 		5 of 1048 (1e-34) AT2G31460(REMB3)/col-AT2G31460-DAP-Seq(GSE60143)/Homer
# 		6 of 1048 (1e-33) SCL(bHLH)/HPC7-Scl-ChIP-Seq(GSE13511)/Homer
# 		7 of 1048 (1e-33) HuR(?)/HEK293-HuR-CLIP-Seq(GSE87887)/Homer
# 		8 of 1048 (1e-32) Initiator/Drosophila-Promoters/Homer
# 		9 of 1048 (1e-28) Hoxd12(Homeobox)/ChickenMSG-Hoxd12.Flag-ChIP-Seq(GSE86088)/Homer
# 		10 of 1048 (1e-26) JGL(C2H2)/col-JGL-DAP-Seq(GSE60143)/Homer
# 		11 of 1048 (1e-26) Foxf1(Forkhead)/Lung-Foxf1-ChIP-Seq(GSE77951)/Homer
# 		12 of 1048 (1e-25) Hoxa9(Homeobox)/ChickenMSG-Hoxa9.Flag-ChIP-Seq(GSE86088)/Homer
# 		13 of 1048 (1e-25) Tcf12(bHLH)/GM12878-Tcf12-ChIP-Seq(GSE32465)/Homer
# 		14 of 1048 (1e-24) STZ(C2H2)/colamp-STZ-DAP-Seq(GSE60143)/Homer
# 		15 of 1048 (1e-23) PHA-4(Forkhead)/cElegans-Embryos-PHA4-ChIP-Seq(modEncode)/Homer
# 		16 of 1048 (1e-22) SeqBias: TA-repeat
# 		17 of 1048 (1e-22) MyoG(bHLH)/C2C12-MyoG-ChIP-Seq(GSE36024)/Homer
# 		18 of 1048 (1e-21) Tcf21(bHLH)/ArterySmoothMuscle-Tcf21-ChIP-Seq(GSE61369)/Homer
# 		19 of 1048 (1e-20) Mef2b(MADS)/HEK293-Mef2b.V5-ChIP-Seq(GSE67450)/Homer
# 		20 of 1048 (1e-19) At5g04390(C2H2)/col200-At5g04390-DAP-Seq(GSE60143)/Homer
# 		21 of 1048 (1e-19) bZIP18(bZIP)/colamp-bZIP18-DAP-Seq(GSE60143)/Homer
# 		22 of 1048 (1e-18) FoxL2(Forkhead)/Ovary-FoxL2-ChIP-Seq(GSE60858)/Homer
# 		23 of 1048 (1e-18) bZIP52(bZIP)/colamp-bZIP52-DAP-Seq(GSE60143)/Homer
# 		24 of 1048 (1e-18) SEP3(MADS)/Arabidoposis-Flower-Sep3-ChIP-Seq/Homer
# 		25 of 1048 (1e-17) hINR(CPE)
# 		26 of 1048 (1e-16) FOXA1(Forkhead)/MCF7-FOXA1-ChIP-Seq(GSE26831)/Homer
# 		27 of 1048 (1e-15) Hoxd10(Homeobox)/ChickenMSG-Hoxd10.Flag-ChIP-Seq(GSE86088)/Homer
# 		28 of 1048 (1e-15) FOXA1(Forkhead)/LNCAP-FOXA1-ChIP-Seq(GSE27824)/Homer
# 		29 of 1048 (1e-15) RLR1?/SacCer-Promoters/Homer
# 		30 of 1048 (1e-15) FOXM1(Forkhead)/MCF7-FOXM1-ChIP-Seq(GSE72977)/Homer
# 		31 of 1048 (1e-15) Mef2d(MADS)/Retina-Mef2d-ChIP-Seq(GSE61391)/Homer
# 		32 of 1048 (1e-14) Bapx1(Homeobox)/VertebralCol-Bapx1-ChIP-Seq(GSE36672)/Homer
# 		33 of 1048 (1e-14) ZBTB38(Zf)/Hela-ZBTB38-ChIP-seq(GSE108618)/Homer
# 		34 of 1048 (1e-14) Nkx2.2(Homeobox)/NPC-Nkx2.2-ChIP-Seq(GSE61673)/Homer
# 		35 of 1048 (1e-14) RIN(MADS)/Tomato-RIN-ChIP-Seq(GSE116581)/Homer
# 		36 of 1048 (1e-14) E2A(bHLH)/proBcell-E2A-ChIP-Seq(GSE21978)/Homer
# 		37 of 1048 (1e-12) Ptf1a(bHLH)/Panc1-Ptf1a-ChIP-Seq(GSE47459)/Homer
# 		38 of 1048 (1e-12) MyoD(bHLH)/Myotube-MyoD-ChIP-Seq(GSE21614)/Homer
# 		39 of 1048 (1e-11) Myf5(bHLH)/GM-Myf5-ChIP-Seq(GSE24852)/Homer
# 		40 of 1048 (1e-11) FOXK1(Forkhead)/HEK293-FOXK1-ChIP-Seq(GSE51673)/Homer
# 		41 of 1048 (1e-11) BHLHA15(bHLH)/NIH3T3-BHLHB8.HA-ChIP-Seq(GSE119782)/Homer
# 		42 of 1048 (1e-11) Ascl2(bHLH)/ESC-Ascl2-ChIP-Seq(GSE97712)/Homer
# 		43 of 1048 (1e-11) Cdx2(Homeobox)/mES-Cdx2-ChIP-Seq(GSE14586)/Homer
# 		44 of 1048 (1e-10) Twist2(bHLH)/Myoblast-Twist2.Ty1-ChIP-Seq(GSE127998)/Homer
# 		45 of 1048 (1e-10) Hoxc13(Homeobox)/EB-Hoxc13.HA-ChIP-Seq(GSE142377)/Homer
# 		46 of 1048 (1e-10) SOL1(CPP)/colamp-SOL1-DAP-Seq(GSE60143)/Homer
# 		47 of 1048 (1e-9) Mef2a(MADS)/HL1-Mef2a.biotin-ChIP-Seq(GSE21529)/Homer
# 		48 of 1048 (1e-9) MafF(bZIP)/HepG2-MafF-ChIP-Seq(GSE31477)/Homer
# 		49 of 1048 (1e-9) MafA(bZIP)/Islet-MafA-ChIP-Seq(GSE30298)/Homer
# 		50 of 1048 (1e-9) GATA20(C2C2gata)/colamp-GATA20-DAP-Seq(GSE60143)/Homer
# 		51 of 1048 (1e-9) Hoxa13(Homeobox)/ChickenMSG-Hoxa13.Flag-ChIP-Seq(GSE86088)/Homer
# 		52 of 1048 (1e-9) HEB(bHLH)/mES-Heb-ChIP-Seq(GSE53233)/Homer
# 		53 of 1048 (1e-9) Foxo3(Forkhead)/U2OS-Foxo3-ChIP-Seq(E-MTAB-2701)/Homer
# 		54 of 1048 (1e-9) Foxh1(Forkhead)/hESC-FOXH1-ChIP-Seq(GSE29422)/Homer
# 		55 of 1048 (1e-9) ERF15(AP2EREBP)/colamp-ERF15-DAP-Seq(GSE60143)/Homer
# 		56 of 1048 (1e-9) Hoxc6(Homeobox)/EB-Hoxc6.iFlag-ChIP-Seq(GSE142377)/Homer
# 		57 of 1048 (1e-9) ANL2(HB)/col-ANL2-DAP-Seq(GSE60143)/Homer
# 		58 of 1048 (1e-9) Unknown2/Drosophila-Promoters/Homer
# 		59 of 1048 (1e-8) Nkx2.5(Homeobox)/HL1-Nkx2.5.biotin-ChIP-Seq(GSE21529)/Homer
# 		60 of 1048 (1e-8) AT2G20110(CPP)/colamp-AT2G20110-DAP-Seq(GSE60143)/Homer
# 		61 of 1048 (1e-8) Ascl1(bHLH)/NeuralTubes-Ascl1-ChIP-Seq(GSE55840)/Homer
# 		62 of 1048 (1e-8) Oct6(POU,Homeobox)/NPC-Pou3f1-ChIP-Seq(GSE35496)/Homer
# 		63 of 1048 (1e-8) HOXD13(Homeobox)/Chicken-Hoxd13-ChIP-Seq(GSE38910)/Homer
# 		64 of 1048 (1e-8) At5g47390(MYBrelated)/col-At5g47390-DAP-Seq(GSE60143)/Homer
# 		65 of 1048 (1e-8) Hoxa10(Homeobox)/ChickenMSG-Hoxa10.Flag-ChIP-Seq(GSE86088)/Homer
# 		66 of 1048 (1e-8) KANADI1(Myb)/Seedling-KAN1-ChIP-Seq(GSE48081)/Homer
# 		67 of 1048 (1e-8) TCX2(CPP)/colamp-TCX2-DAP-Seq(GSE60143)/Homer
# 		68 of 1048 (1e-8) AT5G61620(MYBrelated)/colamp-AT5G61620-DAP-Seq(GSE60143)/Homer
# 		69 of 1048 (1e-7) ZBTB18(Zf)/HEK293-ZBTB18.GFP-ChIP-Seq(GSE58341)/Homer
# 		70 of 1048 (1e-7) AZF1(C2H2)/colamp-AZF1-DAP-Seq(GSE60143)/Homer
# 		71 of 1048 (1e-7) HOXB13(Homeobox)/ProstateTumor-HOXB13-ChIP-Seq(GSE56288)/Homer
# 		72 of 1048 (1e-7) At1g74840(MYBrelated)/col100-At1g74840-DAP-Seq(GSE60143)/Homer
# 		73 of 1048 (1e-7) TCF4(bHLH)/SHSY5Y-TCF4-ChIP-Seq(GSE96915)/Homer
# 		74 of 1048 (1e-6) PU.1-IRF(ETS:IRF)/Bcell-PU.1-ChIP-Seq(GSE21512)/Homer
# 		75 of 1048 (1e-6) Atoh7(bHLH)/Retina-Atoh7-CutnRun(GSE156756)/Homer
# 		76 of 1048 (1e-6) TAGL1(MADS)/Tomato-TAGL1-ChIP-Seq(GSE116581)/Homer
# 		77 of 1048 (1e-6) Bach2(bZIP)/OCILy7-Bach2-ChIP-Seq(GSE44420)/Homer
# 		78 of 1048 (1e-6) Pit1(Homeobox)/GCrat-Pit1-ChIP-Seq(GSE58009)/Homer
# 		79 of 1048 (1e-6) Oct2(POU,Homeobox)/Bcell-Oct2-ChIP-Seq(GSE21512)/Homer
# 		80 of 1048 (1e-6) FoxD3(forkhead)/ZebrafishEmbryo-Foxd3.biotin-ChIP-seq(GSE106676)/Homer
# 		81 of 1048 (1e-6) GATA19(C2C2gata)/colamp-GATA19-DAP-Seq(GSE60143)/Homer
# 		82 of 1048 (1e-6) AT3G57600(AP2EREBP)/col-AT3G57600-DAP-Seq(GSE60143)/Homer
# 		83 of 1048 (1e-6) Mesp1(bHLH)/ESC-Mesp1-ChIP-Seq(GSE165102)/Homer
# 		84 of 1048 (1e-6) caudal(Homeobox)/Drosophila-Embryos-ChIP-Chip(modEncode)/Homer
# 		85 of 1048 (1e-6) ZNF416(Zf)/HEK293-ZNF416.GFP-ChIP-Seq(GSE58341)/Homer
# 		86 of 1048 (1e-5) SeqBias: CG bias
# 		87 of 1048 (1e-5) LIN-39(Homeobox)/cElegans.L3-LIN39-ChIP-Seq(modEncode)/Homer
# 		88 of 1048 (1e-5) HDG1(Homeobox)/col100-HDG1-DAP-Seq(GSE60143)/Homer
# 		89 of 1048 (1e-5) NFATC2(RHD)/Islets-NFATC2-ChIP-Seq(GSE158496)/Homer
# 		90 of 1048 (1e-5) HNF6(Homeobox)/Liver-Hnf6-ChIP-Seq(ERP000394)/Homer
# 		91 of 1048 (1e-5) ASL18(LOBAS2)/colamp-ASL18-DAP-Seq(GSE60143)/Homer
# 		92 of 1048 (1e-5) bZIP:IRF(bZIP,IRF)/Th17-BatF-ChIP-Seq(GSE39756)/Homer
# 		93 of 1048 (1e-5) VIP1(bZIP)/col-VIP1-DAP-Seq(GSE60143)/Homer
# 		94 of 1048 (1e-5) Smad3(MAD)/NPC-Smad3-ChIP-Seq(GSE36673)/Homer
# 		95 of 1048 (1e-5) EGL-5(Homeobox)/cElegans-L3-EGL5-ChIP-Seq(modEncode)/Homer
# 		96 of 1048 (1e-5) AGL63(MADS)/col-AGL63-DAP-Seq(GSE60143)/Homer
# 		97 of 1048 (1e-5) Cux2(Homeobox)/Liver-Cux2-ChIP-Seq(GSE35985)/Homer
# 		98 of 1048 (1e-5) Hoxa11(Homeobox)/ChickenMSG-Hoxa11.Flag-ChIP-Seq(GSE86088)/Homer
# 		99 of 1048 (1e-5) At1g19000(MYBrelated)/colamp-At1g19000-DAP-Seq(GSE60143)/Homer
# 		100 of 1048 (1e-4) KAN2(G2like)/colamp-KAN2-DAP-Seq(GSE60143)/Homer
# 		101 of 1048 (1e-4) GATA4(C2C2gata)/col-GATA4-DAP-Seq(GSE60143)/Homer
# 		102 of 1048 (1e-4) Oct11(POU,Homeobox)/NCIH1048-POU2F3-ChIP-seq(GSE115123)/Homer
# 		103 of 1048 (1e-4) AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer
# 		104 of 1048 (1e-4) Nkx2.1(Homeobox)/LungAC-Nkx2.1-ChIP-Seq(GSE43252)/Homer
# 		105 of 1048 (1e-4) IRF3(IRF)/BMDM-Irf3-ChIP-Seq(GSE67343)/Homer
# 		106 of 1048 (1e-4) ZNF322(Zf)/HEK293-ZNF322.GFP-ChIP-Seq(GSE58341)/Homer
# 		107 of 1048 (1e-4) HIC1(Zf)/Treg-ZBTB29-ChIP-Seq(GSE99889)/Homer
# 		108 of 1048 (1e-4) Hoxc10(Homeobox)/EB-Hoxc10.iFlag-ChIP-Seq(GSE142377)/Homer
# 		109 of 1048 (1e-3) bZIP69(bZIP)/col-bZIP69-DAP-Seq(GSE60143)/Homer
# 		110 of 1048 (1e-3) bHLH80(bHLH)/col-bHLH80-DAP-Seq(GSE60143)/Homer
# 		111 of 1048 (1e-3) Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer
# 		112 of 1048 (1e-3) ZNF7(Zf)/HepG2-ZNF7.Flag-ChIP-Seq(Encode)/Homer
# 		113 of 1048 (1e-3) Atoh1(bHLH)/Cerebellum-Atoh1-ChIP-Seq(GSE22111)/Homer
# 		114 of 1048 (1e-3) WUS1(Homeobox)/colamp-WUS1-DAP-Seq(GSE60143)/Homer
# 		115 of 1048 (1e-3) HDG7(HB)/col-HDG7-DAP-Seq(GSE60143)/Homer
# 		116 of 1048 (1e-3) FOXK2(Forkhead)/U2OS-FOXK2-ChIP-Seq(E-MTAB-2204)/Homer
# 		117 of 1048 (1e-3) AT4G00250(GeBP)/col-AT4G00250-DAP-Seq(GSE60143)/Homer
# 		118 of 1048 (1e-3) Sox7(HMG)/ESC-Sox7-ChIP-Seq(GSE133899)/Homer
# 		119 of 1048 (1e-3) Hoxc9(Homeobox)/Ainv15-Hoxc9-ChIP-Seq(GSE21812)/Homer
# 		120 of 1048 (1e-3) Sox17(HMG)/Endoderm-Sox17-ChIP-Seq(GSE61475)/Homer
# 		121 of 1048 (1e-3) Lola-I(Zf)/Embryo-LolaI-ChIP-Seq(GSE200870)/Homer
# 		122 of 1048 (1e-3) AMYB(HTH)/Testes-AMYB-ChIP-Seq(GSE44588)/Homer
# 		123 of 1048 (1e-3) Oct4(POU,Homeobox)/mES-Oct4-ChIP-Seq(GSE11431)/Homer
# 		124 of 1048 (1e-3) NFAT(RHD)/Jurkat-NFATC1-ChIP-Seq(Jolma_et_al.)/Homer
# 		125 of 1048 (1e-3) At5g08520(MYBrelated)/colamp-At5g08520-DAP-Seq(GSE60143)/Homer
# 		126 of 1048 (1e-3) EIN3(EIL)/col-EIN3-DAP-Seq(GSE60143)/Homer
# 		127 of 1048 (1e-3) LBD23(LOBAS2)/colamp-LBD23-DAP-Seq(GSE60143)/Homer
# 		128 of 1048 (1e-3) ZNF415(Zf)/HEK293-ZNF415.GFP-ChIP-Seq(GSE58341)/Homer
# 		129 of 1048 (1e-3) Egr1(Zf)/K562-Egr1-ChIP-Seq(GSE32465)/Homer
# 		130 of 1048 (1e-3) GRF9(GRF)/colamp-GRF9-DAP-Seq(GSE60143)/Homer
# 		131 of 1048 (1e-2) At5g58900(MYBrelated)/colamp-At5g58900-DAP-Seq(GSE60143)/Homer
# 		132 of 1048 (1e-2) Tal1
# 		133 of 1048 (1e-2) PU.1:IRF8(ETS:IRF)/pDC-Irf8-ChIP-Seq(GSE66899)/Homer
# 		134 of 1048 (1e-2) bHLH122(bHLH)/col100-bHLH122-DAP-Seq(GSE60143)/Homer
# 		135 of 1048 (1e-2) AT5G56840(MYBrelated)/colamp-AT5G56840-DAP-Seq(GSE60143)/Homer
# 		136 of 1048 (1e-2) Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer
# 		137 of 1048 (1e-2) At1g49010(MYBrelated)/col-At1g49010-DAP-Seq(GSE60143)/Homer
# 		138 of 1048 (1e-2) MYB73(MYB)/col-MYB73-DAP-Seq(GSE60143)/Homer
# 		139 of 1048 (1e-2) BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer
# 		140 of 1048 (1e-2) CHR(?)/Hela-CellCycle-Expression/Homer
# 		141 of 1048 (1e-2) AT2G15740(C2H2)/col-AT2G15740-DAP-Seq(GSE60143)/Homer
# 		142 of 1048 (1e-2) Hoxd9(Homeobox)/EB-Hoxd9.HA-ChIP-Seq(GSE142377)/Homer
# 		143 of 1048 (1e-2) Fosl2(bZIP)/3T3L1-Fosl2-ChIP-Seq(GSE56872)/Homer
# 		144 of 1048 (1e-2) Zic3(Zf)/mES-Zic3-ChIP-Seq(GSE37889)/Homer
# 		145 of 1048 (1e-2) PCF/Arabidopsis-Promoters/Homer
# 		146 of 1048 (1e-2) Jun-AP1(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/Homer
# 		147 of 1048 (1e-2) JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE36099)/Homer
# 		148 of 1048 (1e-2) TOD6?/SacCer-Promoters/Homer
# 		149 of 1048 (1e-2) WRKY25(WRKY)/colamp-WRKY25-DAP-Seq(GSE60143)/Homer
# 		150 of 1048 (1e-2) Unknown6/Drosophila-Promoters/Homer
# 		151 of 1048 (1e-2) NeuroG2(bHLH)/Fibroblast-NeuroG2-ChIP-Seq(GSE75910)/Homer
# 		152 of 1048 (1e-2) MYB88(MYB)/col-MYB88-DAP-Seq(GSE60143)/Homer
# 		153 of 1048 (1e-2) NFE2L2(bZIP)/HepG2-NFE2L2-ChIP-Seq(Encode)/Homer
# 		154 of 1048 (1e-2) AT5G23930(mTERF)/col-AT5G23930-DAP-Seq(GSE60143)/Homer
# 		155 of 1048 (1e-2) YY1(Zf)/Promoter/Homer
# 		156 of 1048 (1e-2) Sox2(HMG)/mES-Sox2-ChIP-Seq(GSE11431)/Homer
# 		157 of 1048 (1e-2) Bcl11a(Zf)/HSPC-BCL11A-ChIP-Seq(GSE104676)/Homer
# 		158 of 1048 (1e-2) Meis1(Homeobox)/MastCells-Meis1-ChIP-Seq(GSE48085)/Homer
# 		159 of 1048 (1e-2) CUX1(Homeobox)/K562-CUX1-ChIP-Seq(GSE92882)/Homer
# 		160 of 1048 (1e-2) ASHR1(ND)/col-ASHR1-DAP-Seq(GSE60143)/Homer
# 		161 of 1048 (1e-2) IRF8(IRF)/BMDM-IRF8-ChIP-Seq(GSE77884)/Homer
# 		162 of 1048 (1e-2) WRKY18(WRKY)/col-WRKY18-DAP-Seq(GSE60143)/Homer
#
# 	Progress: Step8 - De novo motif finding (HOMER)
#
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 	Total number of Oligos: 32896
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 32896 of 34497 max
# 	Tree  : 63700 of 172485 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using hypergeometric scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 1 mismatches...
#
# 	Screening oligos 32896 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		6.45% skipped, 93.55% checked (30773 of 32896), of those checked:
# 		6.45% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 32896 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		6.45% skipped, 93.55% checked (30773 of 32896), of those checked:
# 		0.00% not in target, 47.41% increased p-value, 58.41% high p-value
# 	Reading input files...
# 	5993 total sequences read
# 	Cache length = 11180
# 	Using hypergeometric scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: AAAATGAA... (-402.360)
# 		Round 1: -733.35 AAAATGAA T:1892.0(84.94%),B:1009.9(20.94%),P:1e-318
# 		Round 2: -733.35 AAAATGAA T:1892.0(84.94%),B:1009.9(20.94%),P:1e-318
# 		=Final=: -668.55 AAAATGAA T:861.0(86.10%),B:1059.4(24.67%),P:1e-290
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: AGCGCTGG... (-221.181)
# 		Round 1: -323.08 AGCGCTGG T:748.0(52.69%),B:627.0(13.59%),P:1e-140
# 		Round 2: -323.08 AGCGCTGG T:748.0(52.69%),B:627.0(13.59%),P:1e-140
# 		=Final=: -234.14 AGCGCTGG T:483.0(48.30%),B:650.9(15.16%),P:1e-101
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: CAGCTGCA... (-199.177)
# 		Round 1: -352.01 CAGCTGCA T:1176.0(69.17%),B:1197.8(24.33%),P:1e-152
# 		Round 2: -368.83 MARCTGSM T:1571.0(79.23%),B:1707.3(32.80%),P:1e-160
# 		Round 3: -388.37 CAGCTGGA T:1768.0(82.95%),B:1887.3(35.56%),P:1e-168
# 		Round 4: -388.37 CAGCTGGA T:1768.0(82.95%),B:1887.3(35.56%),P:1e-168
# 		=Final=: -368.30 CAGCTGGA T:808.0(80.80%),B:1482.6(34.53%),P:1e-159
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	17 of 25 Initial Sequence: CAGCACTG... (-12.131)
# 		Round 1: -24.78 CAGCACTG T:107.0(10.15%),B:192.4(4.37%),P:1e-10
# 		Round 2: -24.78 CAGCACTG T:107.0(10.15%),B:192.4(4.37%),P:1e-10
# 		=Final=: -27.09 CAGCACTG T:95.0(9.50%),B:161.9(3.77%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	18 of 25 Initial Sequence: TGCCCATC... (-10.012)
# 		Round 1: -6.88 TGCCCATC T:43.0(4.21%),B:101.3(2.32%),P:1e-2
# 		Round 2: -14.57 TVCYCATC T:119.0(11.22%),B:286.9(6.44%),P:1e-6
# 		Round 3: -15.16 TACYCATC T:348.0(29.40%),B:1054.4(21.77%),P:1e-6
# 		Round 4: -16.05 CHCYCATC T:368.0(30.80%),B:1110.9(22.78%),P:1e-6
# 		Round 5: -19.07 TATTCATC T:378.0(31.49%),B:1098.5(22.56%),P:1e-8
# 		Round 6: -20.60 BRTTCATC T:400.0(32.98%),B:1152.9(23.53%),P:1e-8
# 		Round 7: -25.01 YATTCAKC T:291.0(25.26%),B:744.5(15.91%),P:1e-10
# 		Round 8: -25.01 YATTCAKC T:291.0(25.26%),B:744.5(15.91%),P:1e-10
# 		=Final=: -19.87 YATTCAKC T:250.0(25.00%),B:719.4(16.75%),P:1e-8
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	19 of 25 Initial Sequence: ATCCGATG... (-10.657)
# 		Round 1: -26.78 ATCCGATG T:71.0(6.86%),B:93.4(2.14%),P:1e-11
# 		Round 2: -26.78 ATCCGATG T:71.0(6.86%),B:93.4(2.14%),P:1e-11
# 		=Final=: -21.94 ATCCGATG T:61.0(6.10%),B:89.6(2.09%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	20 of 25 Initial Sequence: GACTCGCA... (-9.318)
# 		Round 1: -2.41 CTCACTGA T:35.0(3.44%),B:112.0(2.57%),P:1e-1
# 		Round 2: -5.55 CTCACTGA T:18.0(1.78%),B:31.2(0.72%),P:1e-2
# 		Round 3: -8.98 CYCACTCA T:26.0(2.57%),B:41.0(0.93%),P:1e-3
# 		Round 4: -12.46 CTCACTCV T:39.0(3.83%),B:62.4(1.43%),P:1e-5
# 		Round 5: -12.46 CTCACTCV T:39.0(3.83%),B:62.4(1.43%),P:1e-5
# 		=Final=: -11.45 CTCACTCV T:37.0(3.70%),B:62.4(1.45%),P:1e-4
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	Remaining seeds don't look promising (After initial 5 motifs, logp -8.558 > -9.000)
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	5993 total sequences read
# 	Cache length = 11180
# 	Using hypergeometric scoring
# 	Checking enrichment of 20 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: output_dir/homerMotifs.motifs8
#
#
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 	Total number of Oligos: 467096
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 467096 of 551887 max
# 	Tree  : 945112 of 2759435 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using hypergeometric scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 1 mismatches...
#
# 	Screening oligos 467096 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		67.76% skipped, 32.24% checked (150579 of 467096), of those checked:
# 		67.76% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 467096 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		67.76% skipped, 32.24% checked (150579 of 467096), of those checked:
# 		0.00% not in target, 15.32% increased p-value, 9.51% high p-value
# 	Reading input files...
# 	5993 total sequences read
# 	Cache length = 11180
# 	Using hypergeometric scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: AAAATAAATG... (-264.074)
# 		Round 1: -466.37 AAAATAAATG T:1139.0(68.00%),B:846.9(17.88%),P:1e-202
# 		Round 2: -469.58 AAAATAAATG T:891.0(58.99%),B:536.0(11.71%),P:1e-203
# 		Round 3: -650.72 NAAATAAAWR T:1136.0(67.91%),B:514.9(11.28%),P:1e-282
# 		Round 4: -702.01 MAAATAAAAH T:1472.0(77.07%),B:730.5(15.63%),P:1e-304
# 		Round 5: -734.08 AAAATGAANN T:1991.0(86.36%),B:1080.1(22.24%),P:1e-318
# 		Round 6: -734.08 AAAATGAANN T:1991.0(86.36%),B:1080.1(22.24%),P:1e-318
# 		=Final=: -694.99 AAAATGAANN T:855.0(85.50%),B:987.4(23.00%),P:1e-301
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: TCCAGCGCTG... (-103.302)
# 		Round 1: -361.14 TCCAGCGCTG T:1033.0(64.42%),B:960.6(20.03%),P:1e-156
# 		Round 2: -407.94 YYCAGCGCTG T:962.0(61.81%),B:747.6(15.97%),P:1e-177
# 		Round 3: -411.08 YYCAGCGCTG T:976.0(62.34%),B:758.9(16.18%),P:1e-178
# 		Round 4: -411.08 YYCAGCGCTG T:976.0(62.34%),B:758.9(16.18%),P:1e-178
# 		=Final=: -295.76 YYCAGCGCTG T:504.0(50.40%),B:576.9(13.43%),P:1e-128
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	3 of 25 Initial Sequence: TCGCCATTTT... (-95.882)
# 		Round 1: -293.91 TCGCCATTTT T:596.0(44.92%),B:461.8(10.18%),P:1e-127
# 		Round 2: -420.87 TCBCCATTTT T:1352.0(74.15%),B:1233.4(24.96%),P:1e-182
# 		Round 3: -443.36 TCBCCATTTN T:1599.0(79.81%),B:1477.1(29.11%),P:1e-192
# 		Round 4: -454.39 TCBCCATTTT T:1242.0(71.14%),B:1001.2(20.79%),P:1e-197
# 		Round 5: -454.39 TCBCCATTTT T:1242.0(71.14%),B:1001.2(20.79%),P:1e-197
# 		=Final=: -448.73 TCBCCATTTT T:743.0(74.30%),B:1019.0(23.73%),P:1e-194
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	4 of 25 Initial Sequence: ACTCGAGCTG... (-53.719)
# 		Round 1: -210.74 ACTCGAGCTG T:994.0(63.01%),B:1420.1(28.16%),P:1e-91
# 		Round 2: -277.01 ACTCGAGCTG T:1041.0(64.71%),B:1238.0(25.05%),P:1e-120
# 		Round 3: -308.06 RCTCSAGCTG T:931.0(60.60%),B:954.3(19.92%),P:1e-133
# 		Round 4: -320.55 RCTSSAGCTG T:1085.0(66.23%),B:1160.7(23.67%),P:1e-139
# 		Round 5: -320.55 RCTSSAGCTG T:1085.0(66.23%),B:1160.7(23.67%),P:1e-139
# 		=Final=: -258.77 RCTSSAGCTG T:597.0(59.70%),B:948.2(22.08%),P:1e-112
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	21 of 25 Initial Sequence: GCTCAGCTGA... (-10.971)
# 		Round 1: -28.02 GCTCAGCTGA T:23.0(2.27%),B:5.7(0.12%),P:1e-12
# 		Round 2: -28.02 GCTCAGCTGA T:23.0(2.27%),B:5.7(0.12%),P:1e-12
# 		=Final=: -26.50 GCTCAGCTGA T:21.0(2.10%),B:4.5(0.10%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	22 of 25 Initial Sequence: TCAGCCACTC... (-10.873)
# 		Round 1: -21.15 TCAGCCACTC T:21.0(2.08%),B:8.5(0.19%),P:1e-9
# 		Round 2: -23.77 TCAGCCACTC T:38.0(3.73%),B:32.8(0.74%),P:1e-10
# 		Round 3: -24.26 YCAGCCAYTC T:34.0(3.34%),B:24.0(0.56%),P:1e-10
# 		Round 4: -28.54 TCAGCCAYTC T:45.0(4.40%),B:37.4(0.86%),P:1e-12
# 		Round 5: -30.66 TCAGCCAYTC T:34.0(3.34%),B:16.6(0.37%),P:1e-13
# 		Round 6: -30.66 TCAGCCAYTC T:34.0(3.34%),B:16.6(0.37%),P:1e-13
# 		=Final=: -29.73 TCAGCCAYTC T:33.0(3.30%),B:16.8(0.39%),P:1e-12
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	23 of 25 Initial Sequence: GATATTTATC... (-10.669)
# 		Round 1: -23.52 GATATTTATC T:54.0(5.26%),B:64.0(1.48%),P:1e-10
# 		Round 2: -27.53 GHTATTTATC T:88.0(8.43%),B:132.4(3.03%),P:1e-11
# 		Round 3: -32.90 GHKATTTATC T:129.0(12.11%),B:217.5(4.93%),P:1e-14
# 		Round 4: -32.90 GHKATTTATC T:129.0(12.11%),B:217.5(4.93%),P:1e-14
# 		=Final=: -32.59 GHKATTTATC T:122.0(12.20%),B:215.4(5.02%),P:1e-14
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	24 of 25 Initial Sequence: TCGCTGAATG... (-10.267)
# 		Round 1: -19.77 NCGCTGAATN T:78.0(7.51%),B:137.8(3.14%),P:1e-8
# 		Round 2: -21.78 KCGCTGAATR T:60.0(5.83%),B:83.6(1.91%),P:1e-9
# 		Round 3: -27.84 TMGCTGAATA T:49.0(4.78%),B:44.5(1.02%),P:1e-12
# 		Round 4: -27.84 TMGCTGAATA T:49.0(4.78%),B:44.5(1.02%),P:1e-12
# 		=Final=: -30.50 TMGCTGAATA T:50.0(5.00%),B:44.5(1.04%),P:1e-13
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: CATTCAGTTT... (-10.012)
# 		Round 1: -2.32 CATTCAGTTT T:36.0(3.54%),B:117.5(2.69%),P:1e-1
# 		Round 2: -5.31 CATTCAGTTT T:12.0(1.19%),B:16.7(0.37%),P:1e-2
# 		Round 3: -15.24 BAWTCAGTKT T:89.0(8.52%),B:190.9(4.33%),P:1e-6
# 		Round 4: -15.24 BAWTCAGTKT T:89.0(8.52%),B:190.9(4.33%),P:1e-6
# 		=Final=: -16.19 BAWTCAGTKT T:87.0(8.70%),B:186.1(4.33%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	5993 total sequences read
# 	Cache length = 11180
# 	Using hypergeometric scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: output_dir/homerMotifs.motifs10
#
#
# 	-blen automatically set to 2
# 	Scanning input files...
# 	Parsing sequences...
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 	Total number of Oligos: 1275813
# 	Autoadjustment for sequence coverage in background: 1.00x
#
# 	Oligos: 1275813 of 1426334 max
# 	Tree  : 3302204 of 7131670 max
# 	Optimizing memory usage...
# 	Cache length = 11180
# 	Using hypergeometric scoring
#
# 	Global Optimization Phase: Looking for enriched oligos with up to 1 mismatches...
#
# 	Screening oligos 1275813 (allowing 0 mismatches):
# 	|0%                                   50%                                  100%|
# 	================================================================================
# 		82.65% skipped, 17.35% checked (221360 of 1275813), of those checked:
# 		82.65% not in target, 0.00% increased p-value, 0.00% high p-value
#
# 	Screening oligos 1275813 (allowing 1 mismatches):
# 	|0%                                   50%                                  100%|
# 	===============================================================================
# 		82.65% skipped, 17.35% checked (221360 of 1275813), of those checked:
# 		0.00% not in target, 10.12% increased p-value, 0.49% high p-value
# 	Reading input files...
# 	5993 total sequences read
# 	Cache length = 11180
# 	Using hypergeometric scoring
#
# 	Local Optimization Phase:
# 	1 of 25 Initial Sequence: TTTATTTATTTT... (-112.955)
# 		Round 1: -386.73 TTTATTTATTTT T:1294.0(72.60%),B:1261.3(25.45%),P:1e-167
# 		Round 2: -396.24 TTTATTTATTTT T:846.0(57.11%),B:616.4(13.36%),P:1e-172
# 		Round 3: -420.86 TTTATTTWTTTT T:1294.0(72.60%),B:1159.2(23.66%),P:1e-182
# 		Round 4: -428.56 TTYATTTWTTTT T:1298.0(72.71%),B:1142.8(23.35%),P:1e-186
# 		Round 5: -439.11 TTYATTTWTTTT T:1295.0(72.63%),B:1108.9(22.74%),P:1e-190
# 		Round 6: -439.11 TTYATTTWTTTT T:1295.0(72.63%),B:1108.9(22.74%),P:1e-190
# 		=Final=: -375.10 TTYATTTWTTTT T:617.0(61.70%),B:745.9(17.37%),P:1e-162
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	2 of 25 Initial Sequence: AAATGAAAAATG... (-59.770)
# 		Round 1: -220.43 AAATGAAAAATG T:473.0(37.70%),B:416.8(9.23%),P:1e-95
# 		Round 2: -319.50 AAATGAAAAATG T:792.0(54.72%),B:705.0(15.12%),P:1e-138
# 		Round 3: -377.22 AAATGAARAHTV T:1036.0(64.53%),B:922.6(19.32%),P:1e-163
# 		Round 4: -392.73 AAATGAARAHTV T:1414.0(75.70%),B:1407.3(27.94%),P:1e-170
# 		Round 5: -409.71 AAATGAARAHWN T:1139.0(68.00%),B:982.2(20.44%),P:1e-177
# 		Round 6: -414.87 AAATGAARAHTV T:1044.0(64.81%),B:841.5(17.79%),P:1e-180
# 		Round 7: -414.87 AAATGAARAHTV T:1044.0(64.81%),B:841.5(17.79%),P:1e-180
# 		=Final=: -402.82 AAATGAARAHTV T:636.0(63.60%),B:749.2(17.45%),P:1e-174
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	14 of 25 Initial Sequence: TCAGCTGCGATT... (-11.341)
# 		Round 1: -20.89 TCAGCTGCGATT T:15.0(1.49%),B:2.4(0.05%),P:1e-9
# 		Round 2: -29.34 TCAGYTGCGATT T:33.0(3.25%),B:16.6(0.37%),P:1e-12
# 		Round 3: -34.90 TCAGCTKHGABT T:44.0(4.31%),B:26.0(0.60%),P:1e-15
# 		Round 4: -34.90 TCAGCTKHGABT T:44.0(4.31%),B:26.0(0.60%),P:1e-15
# 		=Final=: -35.05 TCAGCTKHGABT T:45.0(4.50%),B:28.6(0.67%),P:1e-15
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	15 of 25 Initial Sequence: CTAAAATAACTG... (-11.341)
# 		Round 1: -21.15 CTAAAATAACTG T:21.0(2.08%),B:8.5(0.19%),P:1e-9
# 		Round 2: -21.15 CTAAAATAACTG T:21.0(2.08%),B:8.5(0.19%),P:1e-9
# 		=Final=: -21.46 CTAAAATAACTG T:21.0(2.10%),B:8.5(0.20%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	16 of 25 Initial Sequence: TGGAGATCTGTA... (-11.341)
# 		Round 1: -17.37 TGGAGATCTGTA T:21.0(2.08%),B:12.1(0.28%),P:1e-7
# 		Round 2: -17.37 TGGAGATCTGTA T:21.0(2.08%),B:12.1(0.28%),P:1e-7
# 		=Final=: -17.05 TGGAGATCTGTA T:21.0(2.10%),B:13.1(0.31%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	17 of 25 Initial Sequence: TCCAGCCTAAAT... (-10.012)
# 		Round 1: -22.00 TCCAGCCTAAAT T:19.0(1.88%),B:5.1(0.12%),P:1e-9
# 		Round 2: -32.62 TCCAGCCTAAAT T:26.0(2.57%),B:5.7(0.12%),P:1e-14
# 		Round 3: -32.62 TCCAGCCTAAAT T:26.0(2.57%),B:5.7(0.12%),P:1e-14
# 		=Final=: -32.54 TCCAGCCTAAAT T:27.0(2.70%),B:6.6(0.15%),P:1e-14
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	18 of 25 Initial Sequence: CACCCACTCTAG... (-10.012)
# 		Round 1: -15.03 CACCCACTCTAG T:10.0(1.00%),B:0.7(0.00%),P:1e-6
# 		Round 2: -36.96 CACCCACTCTNG T:178.0(16.31%),B:329.2(7.38%),P:1e-16
# 		Round 3: -43.09 CACCCACTCTNG T:149.0(13.85%),B:227.9(5.15%),P:1e-18
# 		Round 4: -48.60 CACCCACTCTNS T:255.0(22.52%),B:479.3(10.56%),P:1e-21
# 		Round 5: -55.17 CWCCCACTCYNS T:201.0(18.22%),B:311.4(6.99%),P:1e-23
# 		Round 6: -55.17 CWCCCACTCYNS T:201.0(18.22%),B:311.4(6.99%),P:1e-23
# 		=Final=: -59.01 CWCCCACTCYNS T:186.0(18.60%),B:298.8(6.96%),P:1e-25
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	24 of 25 Initial Sequence: TAAATAAAAATA... (-10.012)
# 		Round 1: -6.43 TAAATAAAAATA T:11.0(1.09%),B:11.9(0.26%),P:1e-2
# 		Round 2: -6.43 TAAATAAAAATA T:11.0(1.09%),B:11.9(0.26%),P:1e-2
# 		=Final=: -6.50 TAAATAAAAATA T:11.0(1.10%),B:12.3(0.29%),P:1e-2
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: AGCAACAACTGG... (-10.012)
# 		Round 1: -16.08 AGCAACAACTGG T:12.0(1.19%),B:2.5(0.05%),P:1e-6
# 		Round 2: -17.81 AGCAACAACTGG T:17.0(1.69%),B:6.3(0.14%),P:1e-7
# 		Round 3: -17.81 AGCAACAACTGG T:17.0(1.69%),B:6.3(0.14%),P:1e-7
# 		=Final=: -18.08 AGCAACAACTGG T:17.0(1.70%),B:6.3(0.15%),P:1e-7
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	5993 total sequences read
# 	Cache length = 11180
# 	Using hypergeometric scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: output_dir/homerMotifs.motifs12
#
# 	(Motifs in homer2 format)
# 	Determining similar motifs...	70 reduced to 18 motifs
# 	Outputing HTML and sequence logos for motif comparison...
# 	Checking de novo motifs against known motifs...
# 	Formatting HTML page...
# 		1 of 18 (1e-301) similar to SPT23/SPT23_YPD/[](Harbison)/Yeast(0.829)
# 		2 of 18 (1e-206) similar to hINR(CPE)(0.642)
# 		3 of 18 (1e-165) similar to pan/dmmpmm(Bigfoot)/fly(0.847)
# 		4 of 18 (1e-164) similar to BHLHE22/MA1635.2/Jaspar(0.748)
# 		5 of 18 (1e-138) similar to ZIPIC/MA2322.1/Jaspar(0.764)
# 		6 of 18 (1e-111) similar to FEZF2/MA2341.1/Jaspar(0.784)
# 		7 of 18 (1e-102) similar to NKX2-2/MA1645.2/Jaspar(0.696)
# 		8 of 18 (1e-59) similar to CDC5/MA0579.2/Jaspar(0.769)
# 		9 of 18 (1e-50) similar to AT3G46070/MA1381.2/Jaspar(0.734)
# 		10 of 18 (1e-30) similar to slbo/dmmpmm(Down)/fly(0.702)
# 		11 of 18 (1e-30) similar to NHLH1/MA0048.3/Jaspar(0.695)
# 		12 of 18 (1e-24) similar to ROX1/Literature(Harbison)/Yeast(0.800)
# 		13 of 18 (1e-20) similar to GATA20/MA1324.1/Jaspar(0.816)
# 		14 of 18 (1e-13) similar to sens/MA2271.1/Jaspar(0.756)
# 		15 of 18 (1e-13) similar to RVE4/MA1187.2/Jaspar(0.761)
# 		16 of 18 (1e-11) similar to Aef1/dmmpmm(Pollard)/fly(0.773)
# 		17 of 18 (1e-10) similar to NAC079/MA0939.1/Jaspar(0.685)
# 		18 of 18 (1e-7) similar to GATA11/MA1014.1/Jaspar(0.708)
# 	Job finished

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
